# %%
from bs4 import BeautifulSoup
import requests

# %%
URL = requests.get('https://www.wearecms.com/apps/pages/allschools').text

# %%
soup = BeautifulSoup(URL,'lxml')
school = soup.find_all('div')
#print(school.prettify())

# %%
print(school)

#print(summary)
# Out:
# [<div class="header-main-inner">
# <a class="skip-to-content-link" href="#content_main">Skip to main content</a>
# <div class="school-name header-title header-logo logo-replacement">
# <a href="/">
# <span class="school-name-inner">
# 					Charlotte-Mecklenburg Schools
# 				</span>
# </a>
# </div>
# <div class="sitenav-holder megamenu">
# <a class="nav-mobile-toggle" href="#" id="sitenav_main_mobile_toggle">Main Menu Toggle</a>
# <nav aria-label="Main Site Navigation" class="sitenav nav-group" id="sitenav_main">
# <ul class="nav-menu">
# <li class="nav-item">
# <a href="javascript:;"><span class="nav-item-inner">Families</span></a>
# <div class="sub-nav">
# <ul class="sub-nav-group">
# <li><a href="/apps/pages/parentresources">Parent Resources</a></li>
# <li><a href="/apps/pages/index.jsp?uREC_ID=1409791&amp;type=d">Student Portal</a></li>
# <li><a href="/apps/pages/registerforasep">ASEP - After School</a></li>
# ...

# %%
for link in soup.find_all('a'):
    print(link.get('li'))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
print(summary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-7555db655df6> in <module>
# ----> 1 print(summary)
#
# NameError: name 'summary' is not defined
